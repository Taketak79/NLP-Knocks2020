# %%
import MeCab
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams["font.family"] = "IPAexGothic"

# %% [markdown]
# ## 第51問

# %% [markdown]
# ## 第52問

# %% [markdown]
# ## 第53問

# %% [markdown]
# ## 第54問

# %% [markdown]
# ## 第55問

# %% [markdown]
# ## 第56問

# %% [markdown]
# ## 第57問

# %% [markdown]
# ## 第58問

# %% [markdown]
# ## 第59問
